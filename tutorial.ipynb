# %%
import numpy as np
import matplotlib.pyplot as plt
from palette import van_gogh_night, van_gogh_wheatfield, \
monet_irises, monet_sunrise, rainbow

# %%
x=np.linspace(1, 10, 10)
for i in range(5):
    plt.plot(x, x+3*i, color=van_gogh_wheatfield[i], lw=10)

# %%
p= van_gogh_wheatfield

# %%
p.gray()

# %%
p.cvd(cvd_type='deuteranomaly')

# %%
p.cvd(cvd_type='protanomaly')

# %%
p.cvd(cvd_type='tritanomaly')
